# %%
import pandas as pd
from difflib import get_close_matches
import numpy as np
import requests
import json
import time

# %%
def get_pga_data(periodId):
    cookies = {
        '_fbp': 'fb.1.1652982905489.473636789',
        '.ASPXANONYMOUS': '7FPJC4O72AEkAAAANzJhYzQyZTAtMjBlMC00Y2U3LTg0NDgtNGNlYmQ5NzI2Y2Vj0',
        '.DOTNETNUKE': '',
        '_gid': 'GA1.2.1831468145.1658287386',
        'dnn_IsMobile': 'False',
        'language': 'en-US',
        '_ga': 'GA1.2.1013963682.1652982905',
        '_ga_EXD94TY7GX': 'GS1.1.1658331839.119.1.1658331995.0',
    }

    headers = {
        'Accept': 'application/json, text/plain, */*',
        'Accept-Language': 'en-US,en;q=0.9',
        'Connection': 'keep-alive',
        # Requests sorts cookies= alphabetically
        # 'Cookie': '_fbp=fb.1.1652982905489.473636789; .ASPXANONYMOUS=7FPJC4O72AEkAAAANzJhYzQyZTAtMjBlMC00Y2U3LTg0NDgtNGNlYmQ5NzI2Y2Vj0; .DOTNETNUKE=; _gid=GA1.2.1831468145.1658287386; dnn_IsMobile=False; language=en-US; _ga=GA1.2.1013963682.1652982905; _ga_EXD94TY7GX=GS1.1.1658331839.119.1.1658331995.0',
        'DNT': '1',
        'Referer': 'https://www.linestarapp.com/Projections',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-origin',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
        'sec-ch-ua': '".Not/A)Brand";v="99", "Google Chrome";v="103", "Chromium";v="103"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    params = {
        'periodId': periodId,
        'site': '1',
        'sport': '5',
    }

    r = requests.get('https://www.linestarapp.com/DesktopModules/DailyFantasyApi/API/Fantasy/GetSalariesV5', params=params, cookies=cookies, headers=headers)
    r = r.json()
    # If there are no records, return None
    if len(r["Ownership"]["Salaries"]) == 0:
        raise ValueError(f"No data for periodId {periodId}")
    else:
        return r
    

def get_pga_realized_slate(periodId):
    data = get_pga_data(periodId)
    
    main_slate = [x for x in data["Ownership"]["Slates"] if x["SlateName"]=="Main"]
    # Raise errors if there are issues with selecting the right slate
    if len(main_slate) == 0:
        raise ValueError("No Main slate found")
    elif len(main_slate) > 1:
        raise ValueError("Multiple Main slates found")
    else:
        main_slate = main_slate[0]


    # Date of slate geames
    date = main_slate["SlateStart"][0:10]
    # Get SlateId for finding ownership data
    slate_id = main_slate["Id"]
    # Filter players to be those that have strictly positive projection
    slate_players = [x for x in data["Ownership"]["Salaries"] if x["PP"] > 0]
    
    # Make dictionary relating each player ID to projected ownership ammount
    player_ids = [x["PID"] for x in slate_players]
    proj_owned = {x["PlayerId"]: round(x["Owned"] / 100, 2) for x in data["Ownership"]["Projected"][str(slate_id)] if x["PlayerId"] in player_ids}
    # Get realized ownership for GPP tournaments that have contest type 4 on Linestar
    actual_owned = [x["OwnershipData"] for x in data["Ownership"]["ContestResults"] if (x["Contest"]["SlateId"] == slate_id) & (x["Contest"]["ContestType"] == 4)][0]
    actual_owned = {x["PlayerId"]: round(x["Owned"] / 100, 2) for x in actual_owned if x["PlayerId"] in player_ids}
    
    # Adding batting order data
    for player in slate_players:
        try:
            # Adding projected ownership
            player["ProjOwned"] = proj_owned[player["PID"]]
        except KeyError:
            player["ProjOwned"] = 0
            
        try:
            # Adding realized ownership
            player["actual_owned"] = actual_owned[player["PID"]]
        except KeyError:
            player["actual_owned"] = 0


    # Make dictionaries with data we need
    slate_players = [
        {
            "Name": x["Name"],
            "Salary": x["SAL"],
            "Projection": x["PP"],
            "Scored": x["PS"],
            "pOwn": x["ProjOwned"],
            "actOwn": x["actual_owned"]
        }
        for x in slate_players
    ]

    frame = pd.DataFrame(slate_players)
    return (date, frame)


def get_pga_proj_slate(periodId):
    data = get_pga_data(periodId)
    
    main_slate = [x for x in data["Ownership"]["Slates"] if x["SlateName"]=="Main"]
    # Raise errors if there are issues with selecting the right slate
    if len(main_slate) == 0:
        raise ValueError("No Main slate found")
    elif len(main_slate) > 1:
        raise ValueError("Multiple Main slates found")
    else:
        main_slate = main_slate[0]

    # Date of slate geames
    date = main_slate["SlateStart"][0:10]
    # Get SlateId for finding ownership data
    slate_id = [x["SlateId"] for x in main_slate["SlateGames"]][0]
    main_slate_game_ids = [x["GameId"] for x in main_slate["SlateGames"]]
    # Filter players to be those in games in the main slate, and have strictly positive projection
    slate_players = [x for x in data["Ownership"]["Salaries"] if (x["GID"] in main_slate_game_ids) & (x["PP"] > 0)]
    # Construct dictionary relating player IDs to projected ownership
    player_ids = [x["PID"] for x in slate_players]
    proj_owned = {x["PlayerId"]: round(x["Owned"] / 100, 2) for x in data["Ownership"]["Projected"][str(slate_id)] if x["PlayerId"] in player_ids}
    
    for player in slate_players:
        try:
            # Adding projected ownership
            player["ProjOwned"] = proj_owned[player["PID"]]
        except KeyError:
            # If nothing found, assume 0
            player["ProjOwned"] = 0


    # Make dictionaries with data we need
    slate_players = [
        {
            "Name": x["Name"],
            "Salary": x["SAL"],
            "Projection": x["PP"],
            "pOwn": x["ProjOwned"]
        }
        for x in slate_players
    ]

    frame = pd.DataFrame(slate_players)
    return (date, frame)

# %%
# Given a list of periodId's, write realized slates to file
periods = range(255, 342)

for period in periods:
    try:
        print(f"Getting period {period}")
        date, slate = get_pga_realized_slate(period)
        print(f"Writing {date} data to file")
        slate.to_csv(f"./data/pga_realized_slates/{date}.csv", index=False)
    except ValueError as e:
        print(e)
        print("Sleeping for 3 seconds")
        time.sleep(3)
        continue
    print("Sleeping for 3 seconds")
    time.sleep(3)
# Out:
# Getting period 255
# Writing 2020-08-20 data to file
# Sleeping for 3 seconds
# Getting period 256
# Writing 2020-08-27 data to file
# Sleeping for 3 seconds
# Getting period 257
# No Main slate found
# Sleeping for 3 seconds
# Getting period 258
# Writing 2020-09-10 data to file
# Sleeping for 3 seconds
# Getting period 259
# Writing 2020-09-17 data to file
# Sleeping for 3 seconds
# Getting period 260
# Writing 2020-09-24 data to file
# Sleeping for 3 seconds
# Getting period 261
# Writing 2020-10-01 data to file
# Sleeping for 3 seconds
# Getting period 262
# Writing 2020-10-08 data to file
# Sleeping for 3 seconds
# Getting period 263
# Writing 2020-10-15 data to file
# Sleeping for 3 seconds
# Getting period 264
# Writing 2020-10-22 data to file
# Sleeping for 3 seconds
# Getting period 265
# Writing 2020-10-29 data to file
# Sleeping for 3 seconds
# Getting period 266
# No Main slate found
# Sleeping for 3 seconds
# Getting period 267
# Writing 2020-11-12 data to file
# Sleeping for 3 seconds
# Getting period 268
# Writing 2020-11-19 data to file
# Sleeping for 3 seconds
# Getting period 269
# Writing 2020-12-03 data to file
# Sleeping for 3 seconds
# Getting period 270
# Writing 2021-01-07 data to file
# Sleeping for 3 seconds
# Getting period 271
# Writing 2021-01-14 data to file
# Sleeping for 3 seconds
# Getting period 272
# Writing 2021-01-21 data to file
# Sleeping for 3 seconds
# Getting period 273
# Writing 2021-01-28 data to file
# Sleeping for 3 seconds
# Getting period 274
# Writing 2021-02-04 data to file
# Sleeping for 3 seconds
# Getting period 275
# Writing 2021-02-11 data to file
# Sleeping for 3 seconds
# Getting period 276
# Writing 2021-02-18 data to file
# Sleeping for 3 seconds
# Getting period 277
# Writing 2021-02-25 data to file
# Sleeping for 3 seconds
# Getting period 278
# Writing 2021-03-04 data to file
# Sleeping for 3 seconds
# Getting period 279
# Writing 2021-03-11 data to file
# Sleeping for 3 seconds
# Getting period 280
# Writing 2021-03-18 data to file
# Sleeping for 3 seconds
# Getting period 281
# Writing 2021-03-25 data to file
# Sleeping for 3 seconds
# Getting period 282
# No Main slate found
# Sleeping for 3 seconds
# Getting period 283
# Writing 2021-04-08 data to file
# Sleeping for 3 seconds
# Getting period 284
# Writing 2021-04-15 data to file
# Sleeping for 3 seconds
# Getting period 285
# No data for periodId 285
# Sleeping for 3 seconds
# Getting period 286
# Writing 2021-04-29 data to file
# Sleeping for 3 seconds
# Getting period 287
# Writing 2021-05-06 data to file
# Sleeping for 3 seconds
# Getting period 288
# Writing 2021-05-13 data to file
# Sleeping for 3 seconds
# Getting period 289
# Writing 2021-05-20 data to file
# Sleeping for 3 seconds
# Getting period 290
# Writing 2021-05-27 data to file
# Sleeping for 3 seconds
# Getting period 291
# Writing 2021-06-03 data to file
# Sleeping for 3 seconds
# Getting period 292
# Writing 2021-06-10 data to file
# Sleeping for 3 seconds
# Getting period 293
# Writing 2021-06-17 data to file
# Sleeping for 3 seconds
# Getting period 294
# Writing 2021-06-24 data to file
# Sleeping for 3 seconds
# Getting period 295
# Writing 2021-07-01 data to file
# Sleeping for 3 seconds
# Getting period 296
# No Main slate found
# Sleeping for 3 seconds
# Getting period 297
# No Main slate found
# Sleeping for 3 seconds
# Getting period 298
# Writing 2021-07-22 data to file
# Sleeping for 3 seconds
# Getting period 299
# Writing 2021-07-28 data to file
# Sleeping for 3 seconds
# Getting period 300
# Writing 2021-08-05 data to file
# Sleeping for 3 seconds
# Getting period 301
# Writing 2021-08-12 data to file
# Sleeping for 3 seconds
# Getting period 302
# Writing 2021-08-19 data to file
# Sleeping for 3 seconds
# Getting period 303
# Writing 2021-08-26 data to file
# Sleeping for 3 seconds
# Getting period 304
# Writing 2021-09-02 data to file
# Sleeping for 3 seconds
# Getting period 305
# Writing 2021-09-16 data to file
# Sleeping for 3 seconds
# Getting period 306
# Writing 2021-09-30 data to file
# Sleeping for 3 seconds
# Getting period 307
# Writing 2021-10-07 data to file
# Sleeping for 3 seconds
# Getting period 308
# Writing 2021-10-14 data to file
# Sleeping for 3 seconds
# Getting period 309
# Writing 2021-10-20 data to file
# Sleeping for 3 seconds
# Getting period 310
# Writing 2021-10-28 data to file
# Sleeping for 3 seconds
# Getting period 311
# Writing 2021-11-04 data to file
# Sleeping for 3 seconds
# Getting period 312
# Writing 2021-11-11 data to file
# Sleeping for 3 seconds
# Getting period 313
# Writing 2021-11-18 data to file
# Sleeping for 3 seconds
# Getting period 314
# Writing 2021-12-02 data to file
# Sleeping for 3 seconds
# Getting period 315
# Writing 2022-01-06 data to file
# Sleeping for 3 seconds
# Getting period 316
# Writing 2022-01-13 data to file
# Sleeping for 3 seconds
# Getting period 317
# Writing 2022-01-20 data to file
# Sleeping for 3 seconds
# Getting period 318
# Writing 2022-01-26 data to file
# Sleeping for 3 seconds
# Getting period 319
# Writing 2022-02-03 data to file
# Sleeping for 3 seconds
# Getting period 320
# Writing 2022-02-10 data to file
# Sleeping for 3 seconds
# Getting period 321
# Writing 2022-02-17 data to file
# Sleeping for 3 seconds
# Getting period 322
# Writing 2022-02-24 data to file
# Sleeping for 3 seconds
# Getting period 323
# Writing 2022-03-03 data to file
# Sleeping for 3 seconds
# Getting period 324
# Writing 2022-03-10 data to file
# Sleeping for 3 seconds
# Getting period 325
# Writing 2022-03-17 data to file
# Sleeping for 3 seconds
# Getting period 326
# Writing 2022-03-24 data to file
# Sleeping for 3 seconds
# Getting period 327
# No Main slate found
# Sleeping for 3 seconds
# Getting period 328
# Writing 2022-04-07 data to file
# Sleeping for 3 seconds
# Getting period 329
# Writing 2022-04-14 data to file
# Sleeping for 3 seconds
# Getting period 330
# Writing 2022-04-28 data to file
# Sleeping for 3 seconds
# Getting period 331
# Writing 2022-05-05 data to file
# Sleeping for 3 seconds
# Getting period 332
# Writing 2022-05-12 data to file
# Sleeping for 3 seconds
# Getting period 333
# Writing 2022-05-19 data to file
# Sleeping for 3 seconds
# Getting period 334
# Writing 2022-05-26 data to file
# Sleeping for 3 seconds
# Getting period 335
# Writing 2022-06-02 data to file
# Sleeping for 3 seconds
# Getting period 336
# Writing 2022-06-09 data to file
# Sleeping for 3 seconds
# Getting period 337
# Writing 2022-06-16 data to file
# Sleeping for 3 seconds
# Getting period 338
# Writing 2022-06-23 data to file
# Sleeping for 3 seconds
# Getting period 339
# Writing 2022-06-30 data to file
# Sleeping for 3 seconds
# Getting period 340
# No Main slate found
# Sleeping for 3 seconds
# Getting period 341
# Writing 2022-07-13 data to file
# Sleeping for 3 seconds

# %%
# Gathering all historical slates into one file
import os

frames = []
for file in os.listdir("./data/pga_realized_slates"):
    data = pd.read_csv(f"./data/pga_realized_slates/{file}")
    data["Date"] = file[0:10]
    frames.append(data)
    
frame = pd.concat(frames)

# %%
frame.to_csv("./data/pga_hist.csv", index=False)
